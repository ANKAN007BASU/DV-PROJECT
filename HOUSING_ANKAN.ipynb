# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
pari=pd.read_csv('/content/housing parimal.csv')
pari1=pd.DataFrame(pari)
print(pari)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
print(pari.columns)
print(pari.columns.values)
print(pari.values)
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT' 'MEDV']
# [[6.3200e-03 1.8000e+01 2.3100e+00 ... 3.9690e+02 4.9800e+00 2.4000e+01]
#  [2.7310e-02 0.0000e+00 7.0700e+00 ... 3.9690e+02 9.1400e+00 2.1600e+01]
#  [2.7290e-02 0.0000e+00 7.0700e+00 ... 3.9283e+02 4.0300e+00 3.4700e+01]
#  ...
#  [6.0760e-02 0.0000e+00 1.1930e+01 ... 3.9690e+02 5.6400e+00 2.3900e+01]
#  [1.0959e-01 0.0000e+00 1.1930e+01 ... 3.9345e+02 6.4800e+00 2.2000e+01]
#  [4.7410e-02 0.0000e+00 1.1930e+01 ... 3.9690e+02 7.8800e+00 1.1900e+01]]

# %%
print(pari.head(6))
print(pari.tail(6))
print(pari[20:30])
print(pari.shape)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2
# 5  394.12   5.21  28.7
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 500  0.22438  0.0   9.69   0.0  0.585  6.027  79.7  2.4982    6  391     19.2
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273     21.0
# ...

# %%
print(pari.iloc[0,4])
print(pari.loc[[0,1]])
# Out:
# 0.538
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
#
#        B  LSTAT  MEDV
# 0  396.9   4.98  24.0
# 1  396.9   9.14  21.6

# %%
print(pari["NOX"].mean())
print(pari["NOX"].median())
print(pari["NOX"].mode()[0])
print(pari["NOX"].max())
print(pari["NOX"].min())
# Out:
# 0.5546950592885376
# 0.538
# 0.538
# 0.871
# 0.385

# %%
pari.shape
# Out:
# (506, 14)

# %%
print(pari.groupby(["NOX","RM"]).sum())
# Out:
#                 CRIM    ZN  INDUS  CHAS    AGE     DIS  RAD  TAX  PTRATIO  \
# NOX   RM
# 0.385 6.230  0.01965  80.0   1.76   0.0    0.0  9.0892    1  241     18.2
# 0.389 6.453  0.01096  55.0   2.25   0.0   31.9  7.3073    1  300     15.3
# 0.392 5.876  0.03548  80.0   3.64   0.0   19.1  9.2203    1  315     16.4
#       6.108  0.04819  80.0   3.64   0.0   32.0  9.2203    1  315     16.4
# 0.394 7.454  0.01538  90.0   3.75   0.0   34.2  6.3361    3  244     15.9
# ...              ...   ...    ...   ...    ...     ...  ...  ...      ...
# 0.871 6.122  1.65660   0.0  19.58   0.0    0.0  1.6180    5  403     14.7
#       6.129  1.41385   0.0  19.58   1.0   96.0  1.7494    5  403     14.7
#       6.130  2.37934   0.0  19.58   0.0  100.0  1.4191    5  403     14.7
#       6.152  3.53501   0.0  19.58   1.0    0.0  1.7455    5  403     14.7
#       6.510  1.42502   0.0  19.58   0.0  100.0  1.7659    5  403     14.7
#
#                   B  LSTAT  MEDV
# NOX   RM
# ...

# %%
print(pari.isnull())
print(pari.isnull().sum())
# Out:
#       CRIM     ZN  INDUS   CHAS    NOX     RM    AGE    DIS    RAD    TAX  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 501  False  False  False  False  False  False  False  False  False  False
# 502  False  False  False  False  False  False  False  False  False  False
# 503  False  False  False  False  False  False  False  False  False  False
# 504  False  False  False  False  False  False  False  False  False  False
# 505  False  False  False  False  False  False   True  False  False  False
#
#      PTRATIO      B  LSTAT   MEDV
# 0      False  False  False  False
# ...

# %%
print(pari1.dropna())
pari1.fillna(10,inplace=True)
print(pari1)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 5    0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 499  0.17783   0.0   9.69   0.0  0.585  5.569  73.5  2.3999    6  391
# 500  0.22438   0.0   9.69   0.0  0.585  6.027  79.7  2.4982    6  391
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
pari['RM'].corr(pari['AGE'])
# Out:
# -0.23209560194851192

# %%
sns.boxplot(data=pari,x='NOX')
# Out:
# <Axes: xlabel='NOX'>

# %%
corr = pari[["NOX","RM"]].corr()
sns.heatmap(corr)
plt.show()

# %%
sns.histplot(data=pari["DIS"])
# Out:
# <Axes: xlabel='DIS', ylabel='Count'>

# %%
sns.displot(pari["AGE"], bins=10, kde=True)

# %%
sns.scatterplot(x="RM",y="DIS",data=pari)
plt.show()
