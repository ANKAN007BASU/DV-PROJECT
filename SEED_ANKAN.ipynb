# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv("/content/seeds.csv")
df=pd.DataFrame(data)
print(data)
# Out:
#       Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0    15.26      14.84       0.8710          5.763         3.312
# 1    14.88      14.57       0.8811          5.554         3.333
# 2    14.29      14.09       0.9050          5.291         3.337
# 3    13.84      13.94       0.8955          5.324         3.379
# 4    16.14      14.99       0.9034          5.658         3.562
# ..     ...        ...          ...            ...           ...
# 194  12.19      13.20       0.8783          5.137         2.981
# 195  11.23      12.88       0.8511          5.140         2.795
# 196  13.20      13.66       0.8883          5.236         3.232
# 197  11.84      13.21       0.8521          5.175         2.836
# 198  12.30      13.34       0.8684          5.243         2.974
#
#      Asymmetry.Coeff  Kernel.Groove  Type
# 0              2.221          5.220     1
# 1              1.018          4.956     1
# 2              2.699          4.825     1
# ...

# %%
print(df.info())
print(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             199 non-null    float64
#  1   Perimeter        199 non-null    float64
#  2   Compactness      199 non-null    float64
#  3   Kernel.Length    199 non-null    float64
#  4   Kernel.Width     199 non-null    float64
#  5   Asymmetry.Coeff  199 non-null    float64
#  6   Kernel.Groove    199 non-null    float64
#  7   Type             199 non-null    int64
# dtypes: float64(7), int64(1)
# memory usage: 12.6 KB
# None
#              Area   Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# count  199.000000  199.000000   199.000000     199.000000    199.000000
# mean    14.918744   14.595829     0.870811       5.643151      3.265533
# std      2.919976    1.310445     0.023320       0.443593      0.378322
# ...

# %%
print(data.head(6))
print(data.tail(6))
print(data[20:30])
print(data.shape)
# Out:
#     Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0  15.26      14.84       0.8710          5.763         3.312
# 1  14.88      14.57       0.8811          5.554         3.333
# 2  14.29      14.09       0.9050          5.291         3.337
# 3  13.84      13.94       0.8955          5.324         3.379
# 4  16.14      14.99       0.9034          5.658         3.562
# 5  14.38      14.21       0.8951          5.386         3.312
#
#    Asymmetry.Coeff  Kernel.Groove  Type
# 0            2.221          5.220     1
# 1            1.018          4.956     1
# 2            2.699          4.825     1
# 3            2.259          4.805     1
# 4            1.355          5.175     1
# 5            2.462          4.956     1
#       Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 193  12.37      13.47       0.8567          5.204         2.960
# 194  12.19      13.20       0.8783          5.137         2.981
# ...

# %%
print(data.iloc[0,4])
print(data.loc[[0,1]])
# Out:
# 3.312
#     Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0  15.26      14.84       0.8710          5.763         3.312
# 1  14.88      14.57       0.8811          5.554         3.333
#
#    Asymmetry.Coeff  Kernel.Groove  Type
# 0            2.221          5.220     1
# 1            1.018          4.956     1

# %%
print(data["Perimeter"].mean())
print(data["Perimeter"].median())
print(data["Perimeter"].mode()[0])
print(data["Perimeter"].max())
print(data["Perimeter"].min())
# Out:
# 14.595829145728644
# 14.37
# 13.47
# 17.25
# 12.41

# %%
print(data.groupby(["Perimeter","Area"]).sum())
# Out:
#                  Compactness  Kernel.Length  Kernel.Width  Asymmetry.Coeff  \
# Perimeter Area
# 12.41     10.59       0.8648          4.899         2.787            4.975
# 12.57     10.80       0.8590          4.981         2.821            4.773
# 12.63     11.23       0.8840          4.902         2.879            2.269
# 12.72     11.18       0.8680          5.009         2.810            4.051
# 12.73     10.74       0.8329          5.145         2.642            4.702
# ...                      ...            ...           ...              ...
# 17.03     20.16       0.8735          6.513         3.773            1.910
# 17.05     20.88       0.9031          6.450         4.032            5.016
# 17.21     21.18       0.8989          6.573         4.033            5.780
# 17.23     20.71       0.8763          6.579         3.814            4.451
# 17.25     20.97       0.8859          6.563         3.991            4.677
#
#                  Kernel.Groove  Type
# ...

# %%
print(data.isnull())
print(data.isnull().sum())
# Out:
#       Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0    False      False        False          False         False
# 1    False      False        False          False         False
# 2    False      False        False          False         False
# 3    False      False        False          False         False
# 4    False      False        False          False         False
# ..     ...        ...          ...            ...           ...
# 194  False      False        False          False         False
# 195  False      False        False          False         False
# 196  False      False        False          False         False
# 197  False      False        False          False         False
# 198  False      False        False          False         False
#
#      Asymmetry.Coeff  Kernel.Groove   Type
# 0              False          False  False
# 1              False          False  False
# 2              False          False  False
# ...

# %%
print(df.dropna())
df.fillna(101,inplace=True)
print(df)
# Out:
#       Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0    15.26      14.84       0.8710          5.763         3.312
# 1    14.88      14.57       0.8811          5.554         3.333
# 2    14.29      14.09       0.9050          5.291         3.337
# 3    13.84      13.94       0.8955          5.324         3.379
# 4    16.14      14.99       0.9034          5.658         3.562
# ..     ...        ...          ...            ...           ...
# 194  12.19      13.20       0.8783          5.137         2.981
# 195  11.23      12.88       0.8511          5.140         2.795
# 196  13.20      13.66       0.8883          5.236         3.232
# 197  11.84      13.21       0.8521          5.175         2.836
# 198  12.30      13.34       0.8684          5.243         2.974
#
#      Asymmetry.Coeff  Kernel.Groove  Type
# 0              2.221          5.220     1
# 1              1.018          4.956     1
# 2              2.699          4.825     1
# ...

# %%
data['Perimeter'].corr(data['Area'])
# Out:
# 0.994437254697115

# %%
sns.boxplot(data=data,x='Area')
plt.show()

# %%
corr = data[["Area","Perimeter"]].corr()
sns.heatmap(corr)
plt.show()

# %%
sns.barplot(data=data['Perimeter'])
# Out:
# <Axes: ylabel='Perimeter'>

# %%
sns.displot(data["Area"], bins=10, kde=True)

# %%
sns.histplot(data=data["Area"])
# Out:
# <Axes: xlabel='Area', ylabel='Count'>

# %%
sns.displot(data["Area"], bins=10, kde=True)

# %%
sns.scatterplot(x="Area",y="Perimeter",data=data)
plt.show()
