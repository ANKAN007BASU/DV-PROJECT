# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
pari=pd.read_csv('/content/abalone.csv')
pari1=pd.DataFrame(pari)
print(pari)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
print(pari.columns)
print(pari.columns.values)
print(pari.values)
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')
# ['Sex' 'Length' 'Diameter' 'Height' 'Whole weight' 'Shucked weight'
#  'Viscera weight' 'Shell weight' 'Rings']
# [['M' 0.455 0.365 ... 0.101 0.15 15]
#  ['M' 0.35 0.265 ... 0.0485 0.07 7]
#  ['F' 0.53 0.42 ... 0.1415 0.21 9]
#  ...
#  ['M' 0.6 0.475 ... 0.2875 0.308 9]
#  ['F' 0.625 0.485 ... 0.261 0.296 10]
#  ['M' 0.71 0.555 ... 0.3765 0.495 12]]

# %%
print(pari.head(6))
print(pari.tail(6))
print(pari[20:30])
print(pari.shape)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
# 5   I   0.425     0.300   0.095        0.3515          0.1410          0.0775
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7
# 5         0.120      8
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4171   M   0.560     0.430   0.155        0.8675          0.4000
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# ...

# %%
print(pari.iloc[0,4])
print(pari.loc[[0,1]])
# Out:
# 0.514
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
#
#    Shell weight  Rings
# 0          0.15     15
# 1          0.07      7

# %%
print(pari["Height"].mean())
print(pari["Height"].median())
print(pari["Height"].mode()[0])
print(pari["Height"].max())
print(pari["Height"].min())
# Out:
# 0.13951639932966242
# 0.14
# 0.15
# 1.13
# 0.0

# %%
pari.shape
# Out:
# (4177, 9)

# %%
print(pari.groupby(["Height","Diameter"]).sum())
# Out:
#                 Sex  Length  Whole weight  Shucked weight  Viscera weight  \
# Height Diameter
# 0.000  0.230      I   0.315        0.1340          0.0575          0.0285
#        0.340      I   0.430        0.4280          0.2065          0.0860
# 0.010  0.055      I   0.075        0.0020          0.0010          0.0005
# 0.015  0.115      I   0.165        0.0145          0.0055          0.0030
#        0.495      F   0.635        1.1565          0.5115          0.3080
# ...              ..     ...           ...             ...             ...
# 0.250  0.470      F   0.595        1.2830          0.4620          0.2475
#        0.630      M   0.775        2.7795          1.3485          0.7600
#        0.650      F   0.815        2.2550          0.8905          0.4200
# 0.515  0.565      M   0.705        2.2100          1.1075          0.4865
# 1.130  0.355      F   0.455        0.5940          0.3320          0.1160
#
#                  Shell weight  Rings
# Height Diameter
# ...

# %%
print(pari.isnull())
print(pari.isnull().sum())
# Out:
#         Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     False   False     False   False         False           False
# 1     False   False     False   False         False           False
# 2     False   False     False   False         False           False
# 3     False   False     False   False         False           False
# 4     False   False     False   False         False           False
# ...     ...     ...       ...     ...           ...             ...
# 4172  False   False     False   False         False           False
# 4173  False   False     False   False         False           False
# 4174  False   False     False   False         False           False
# 4175  False   False     False   False         False           False
# 4176  False   False     False   False         False           False
#
#       Viscera weight  Shell weight  Rings
# 0              False         False  False
# 1              False         False  False
# ...

# %%
print(pari1.dropna())
pari1.fillna(10,inplace=True)
print(pari1)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
pari['Height'].corr(pari['Diameter'])
# Out:
# 0.8336836879586539

# %%
sns.boxplot(data=pari,x='Length',y='Height')
# Out:
# <Axes: xlabel='Length', ylabel='Height'>

# %%
corr = pari[["Length","Diameter"]].corr()
sns.heatmap(corr)
plt.show()

# %%
sns.histplot(data=pari["Height"])
# Out:
# <Axes: xlabel='Height', ylabel='Count'>

# %%
sns.displot(pari["Diameter"], bins=10, kde=True)

# %%
sns.scatterplot(x="Diameter",y="Height",data=pari)
plt.show()
